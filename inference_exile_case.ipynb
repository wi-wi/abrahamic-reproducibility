# %% [markdown]
# # Bayesian Inference Notebook
# Implements ODE model + PyMC inference.

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
df = pd.read_csv('proxies_babylonian_normalized.csv')
df

# %% [markdown]
# ## Define model RHS

# %%
def rhs(x, t, beta, eta, v, gamma):
    return (beta + eta*v)*x*(1-x) - gamma*x
